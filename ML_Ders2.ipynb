# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df = pd.read_csv('student.csv')
df.head(3)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811

# %%
df.columns=['sinif','saat','puan']
df.head(3)
# Out:
#    sinif   saat    puan
# 0      3  4.508  19.202
# 1      4  0.096   7.734
# 2      4  3.133  13.811

# %%
y = df[["puan"]]
x = df[["sinif","saat"]]

# %%
lm = LinearRegression()
model = lm.fit(x,y)

# %% [markdown]
# y = ax + b

# %%
model.coef_ #katsayı  a1.x1  a2.x2 bulur
# Out:
# array([[1.86405074, 5.39917879]])

# %%
model.intercept_ #sabit yani formüldeki b yi buluyor
# Out:
# array([-7.45634623])

# %%
model.predict([[4,3]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16.1973931]])

# %%
df.head(3)
# Out:
#    sinif   saat    puan
# 0      3  4.508  19.202
# 1      4  0.096   7.734
# 2      4  3.133  13.811

# %%
model.predict([[3,4.508]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[22.47530397]])

# %%
s1 = model.predict([[3,4.508]])[0][0]
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
-(19.202-s1)/19.202
# Out:
# np.float64(0.17046682485899442)

# %%
model.score(x,y)
# Out:
# 0.9403656320238896
